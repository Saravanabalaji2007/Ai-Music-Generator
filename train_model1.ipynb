# %%
import numpy as np

network_input = np.load("network_input.npy")
network_output = np.load("network_output.npy")

print(network_input.shape)
print(network_output.shape)
# Out:
# (65550, 100, 1)
# (65550, 1346)

# %%
network_input = network_input[:10000]
network_output = network_output[:10000]

print(network_input.shape)
print(network_output.shape)
# Out:
# (10000, 100, 1)
# (10000, 1346)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

model = Sequential()

model.add(
    Input(
        shape=(
            network_input.shape[1],
            network_input.shape[2]
        )
    )
)

model.add(
    LSTM(64)
)

# %%
model.add(
    Dropout(0.2)
)

model.add(
    Dense(
        64,
        activation="relu"
    )
)

model.add(
    Dense(
        network_output.shape[1],
        activation="softmax"
    )
)

print("Model Built Successfully")
# Out:
# Model Built Successfully

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1346)                │          87,490 │
# ...

# %%
model.compile(
    loss="categorical_crossentropy",
    optimizer="adam",
    metrics=["accuracy"]
)

print("Model Compiled Successfully")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model Compiled Successfully

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint(
    "best_model.keras",
    monitor="loss",
    save_best_only=True,
    verbose=1
)

print("Checkpoint Created")
# Out:
# Checkpoint Created

# %%
network_input = network_input[:20000]
network_output = network_output[:20000]

print(network_input.shape)
print(network_output.shape)
# Out:
# (5000, 100, 1)
# (5000, 1346)

# %%
history = model.fit(
    network_input,
    network_output,
    epochs=10,
    batch_size=16,
    validation_split=0.1,
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/10
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.0368 - loss: 4.2145
# Epoch 1: loss improved from 4.25471 to 4.24674, saving model to best_model.keras
#
# Epoch 1: finished saving model to best_model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 18s 51ms/step - accuracy: 0.0373 - loss: 4.2467 - val_accuracy: 0.0320 - val_loss: 4.3778
# Epoch 2/10
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.0382 - loss: 4.2393
# Epoch 2: loss improved from 4.24674 to 4.24342, saving model to best_model.keras
#
# Epoch 2: finished saving model to best_model.keras
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step - accuracy: 0.0364 - loss: 4.2434 - val_accuracy: 0.0320 - val_loss: 4.3442
# Epoch 3/10
# 281/282 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.0320 - loss: 4.2525
# Epoch 3: loss improved from 4.24342 to 4.24165, saving model to best_model.keras
#
# Epoch 3: finished saving model to best_model.keras
# ...

# %%
model.save("music_model.h5")

print("Model Saved Successfully")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model Saved Successfully

# %%
import os

print(os.path.exists("best_model.keras"))
print(os.path.exists("music_model.h5"))
# Out:
# True
# True

# %%
import pickle
import numpy as np

from tensorflow.keras.models import load_model

model = load_model("best_model.keras")

print("Model Loaded Successfully")
# Out:
# Model Loaded Successfully
